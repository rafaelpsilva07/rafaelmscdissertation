# %%
import matplotlib.pyplot as plt
import numpy as np

import db_24_plies

# %%
db = db_24_plies.db_24_plies

# %%
xiD = np.array(
    list(db.keys()))
xiD.shape
# Out:
# (518, 2)

# %%
plt.plot(xiD[::, 0], xiD[::, 1], 'o')
plt.xlabel('xi1D')
plt.ylabel('xi3D')
plt.title('24 plies')
plt.grid()
