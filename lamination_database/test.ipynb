# %%
import matplotlib.pyplot as plt
import numpy as np

import db_23_plies

# %%
db21 = db_23_plies.db_23_plies

# %%
xiD = np.array(
    list(db21.keys()))
xiD.shape
# Out:
# (533, 2)

# %%
plt.plot(xiD[::, 0], xiD[::, 1], 'o')
