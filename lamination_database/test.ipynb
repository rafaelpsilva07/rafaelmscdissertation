# %%
import matplotlib.pyplot as plt
import numpy as np

import db_165_plies

# %%
db = db_165_plies.db_165_plies

# %%
xiD = np.array(
    list(db.keys()))
xiD.shape
# Out:
# (220, 2)

# %%
plt.plot(xiD[::, 0], xiD[::, 1], 'o')
