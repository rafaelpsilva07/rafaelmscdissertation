# %% [markdown]
# Examples of contour plots to discut differentiabillity

# %%
E1 = 100e3
E2 = 10e3
G12 = 6.4e3
v12 = 0.3
a = 100
b = 10
m = 7
n = 7
panel_constraint = 'PINNED'
#panel_constraint = 'CLAMPED'

Nxx = -1
Nyy = -1
Nxy = -0

# %%
from composipy.optimize import maximize_buckling_load

# %%
maximize_buckling_load(a, b, 8*0.127, E1, E2, v12, G12, Nxx, Nyy, Nxy, panel_constraint=panel_constraint, m=4, n=4, plot=True, points_to_plot=30)
# Out:
# generating plot...
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -775.6163056076556
#        x: [-1.000e+00  9.999e-01]
#      nit: 3
#      jac: [ 3.006e+02  1.020e+01]
#     nfev: 9
#     njev: 3
